# %% [markdown]
# <a href="https://colab.research.google.com/github/marcoantonioafernandes/bootcamp_data_science_aulas/blob/main/plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A151346189_28_143_208.csv'

full_data = pd.read_csv(url, encoding="ISO-8859-1", skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")
full_data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
#   Unidade da Federação     2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia   1388528.39  ...  10285455.78  9.291297e+08
# 1              12 Acre    902416.00  ...            -  4.206680e+08
# 2          13 Amazonas   4735529.42  ...  14726443.67  1.771655e+09
# 3           14 Roraima    657889.53  ...   2826486.18  3.050109e+08
# 4              15 Pará  18864744.11  ...  39911193.02  4.437116e+09
#
# [5 rows x 154 columns]

# %%
#Vamos resolver a linha total
#axis = 0 coluna - axis = 1 linha
full_data = full_data.drop("Total", axis=1)

# %%
full_data
# Out:
#       Unidade da Federação     2008/Jan  ...      2020/Jul      2020/Ago
# 0              11 Rondônia   1388528.39  ...  1.115211e+07   10285455.78
# 1                  12 Acre    902416.00  ...  3.915193e+06             -
# 2              13 Amazonas   4735529.42  ...  1.934645e+07   14726443.67
# 3               14 Roraima    657889.53  ...  3.015488e+06    2826486.18
# 4                  15 Pará  18864744.11  ...  3.843887e+07   39911193.02
# 5                 16 Amapá   1120973.34  ...  3.249566e+06    2942273.94
# 6             17 Tocantins   3441592.69  ...  9.131708e+06    8240261.38
# 7              21 Maranhão  10723506.39  ...  3.293650e+07   28587541.78
# 8                 22 Piauí   7985142.43  ...  1.787160e+07   23210624.20
# 9                 23 Ceará  15539821.90  ...  5.518075e+07   59808605.59
# 10  24 Rio Grande do Norte   5947814.08  ...  2.630237e+07   24929930.72
# 11              25 Paraíba  10723002.45  ...  2.690244e+07   22130016.81
# ...

# %%
util_columns = full_data.mean().index.tolist()
util_columns.insert(0, "Unidade da Federação")

util_columns[:5]
# Out:
# ['Unidade da Federação', '2008/Jan', '2008/Fev', '2008/Mar', '2008/Abr']

# %%
util_data = full_data[util_columns]

# %%
util_data = util_data.set_index("Unidade da Federação")
util_data.head()
# Out:
#                          2008/Jan     2008/Fev  ...     2020/Jun     2020/Jul
# Unidade da Federação                            ...
# 11 Rondônia            1388528.39   2931283.42  ...   8725530.68  11152107.08
# 12 Acre                 902416.00   1497206.26  ...   3045245.80   3915193.20
# 13 Amazonas            4735529.42   7118990.57  ...  20897542.93  19346450.18
# 14 Roraima              657889.53    777939.31  ...   3401864.29   3015488.30
# 15 Pará               18864744.11  19553758.20  ...  41625331.28  38438873.79
#
# [5 rows x 150 columns]

# %%
import matplotlib.pyplot as plt

states = ["31 Minas Gerais", "35 São Paulo", "33 Rio de Janeiro", "43 Rio Grande do Sul", "13 Amazonas"]
ax = util_data.loc[states].T.plot(figsize=(10,8))
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# %% [markdown]
# A partir daqui vamos plotar usando o plotly

# %%
import plotly.graph_objects as go
# Out:
# Index(['31 Minas Gerais', '35 São Paulo', '33 Rio de Janeiro',
#        '43 Rio Grande do Sul', '13 Amazonas'],
#       dtype='object', name='Unidade da Federação')

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=util_data.loc[states].columns, y=util_data.loc["31 Minas Gerais"], name="Minas Gerais"))
fig.add_trace(go.Scatter(x=util_data.loc[states].columns, y=util_data.loc["35 São Paulo"], name="São Paulo"))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e3f60c73-d4c4-4c88-823f-743d3836a4fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e3f60c73-d4c4-4c88-823f-743d3836a4fb")) {
#                     Plotly.newPlot(
#                         'e3f60c73-d4c4-4c88-823f-743d3836a4fb',
# ...

# %%
import plotly.express as px
# Out:
# '2020/Jul'

# %%
last_month = util_data.loc[states].columns[-1]
fig2 = px.bar(x=util_data.loc[states].index, y=util_data.loc[states][last_month], labels={'x':'Unidade da Federação', 'y':'Gastos do último mês'})
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="59b8ddf0-cd4b-4ba4-bfe3-6cd0a67da0e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("59b8ddf0-cd4b-4ba4-bfe3-6cd0a67da0e3")) {
#                     Plotly.newPlot(
#                         '59b8ddf0-cd4b-4ba4-bfe3-6cd0a67da0e3',
# ...

# %%
fig2.write_html('imagem.html')
